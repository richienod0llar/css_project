# %% [markdown]
# # Chromatic Mood of Fashion Eras
#
# **Goal:** Analyze how color palettes in Vogue runway images change over time using the Sanzo Wada color dataset.
#
# This notebook provides a complete workflow for analyzing the chromatic evolution of fashion from the 1980s to present.

# %% [markdown]
# ## 1. Setup and Imports

# %%
import sys
# !{sys.executable} -m pip install opencv-python
# Out:
# Collecting opencv-python
#   Using cached opencv_python-4.12.0.88-cp37-abi3-macosx_13_0_arm64.whl.metadata (19 kB)
# Requirement already satisfied: numpy<2.3.0,>=2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from opencv-python) (2.2.2)
# Using cached opencv_python-4.12.0.88-cp37-abi3-macosx_13_0_arm64.whl (37.9 MB)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.12.0.88
#
# [notice] A new release of pip is available: 25.0 -> 25.3
# [notice] To update, run: /Library/Frameworks/Python.framework/Versions/3.13/bin/python3.13 -m pip install --upgrade pip

# %%
# !pip install numpy
# !pip install pandas
# !pip install pathlib
# !pip install tqdm
# !pip install matplotlib
# !pip install scikit-learn
# !pip install pillow
# !pip install opencv-python
# !pip install plotly
# !pip install colormath
# Out:
# Requirement already satisfied: numpy in /Users/richienodollar/.pyenv/versions/3.10.0/lib/python3.10/site-packages (2.1.3)
# Requirement already satisfied: pandas in /Users/richienodollar/.pyenv/versions/3.10.0/lib/python3.10/site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.22.4 in /Users/richienodollar/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from pandas) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/richienodollar/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/richienodollar/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/richienodollar/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /Users/richienodollar/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: pathlib in /Users/richienodollar/.pyenv/versions/3.10.0/lib/python3.10/site-packages (1.0.1)
# Requirement already satisfied: tqdm in /Users/richienodollar/.pyenv/versions/3.10.0/lib/python3.10/site-packages (4.67.1)
# Requirement already satisfied: matplotlib in /Users/richienodollar/.pyenv/versions/3.10.0/lib/python3.10/site-packages (3.10.3)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/richienodollar/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /Users/richienodollar/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/richienodollar/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from matplotlib) (4.58.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/richienodollar/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in /Users/richienodollar/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from matplotlib) (2.1.3)
# Requirement already satisfied: packaging>=20.0 in /Users/richienodollar/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /Users/richienodollar/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/richienodollar/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/richienodollar/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/richienodollar/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: scikit-learn in /Users/richienodollar/.pyenv/versions/3.10.0/lib/python3.10/site-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in /Users/richienodollar/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from scikit-learn) (2.1.3)
# Requirement already satisfied: scipy>=1.6.0 in /Users/richienodollar/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in /Users/richienodollar/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/richienodollar/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: pillow in /Users/richienodollar/.pyenv/versions/3.10.0/lib/python3.10/site-packages (11.2.1)
# Requirement already satisfied: opencv-python in /Users/richienodollar/.pyenv/versions/3.10.0/lib/python3.10/site-packages (4.11.0.86)
# Requirement already satisfied: numpy>=1.21.2 in /Users/richienodollar/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from opencv-python) (2.1.3)
# Requirement already satisfied: plotly in /Users/richienodollar/.pyenv/versions/3.10.0/lib/python3.10/site-packages (6.5.0)
# Requirement already satisfied: narwhals>=1.15.1 in /Users/richienodollar/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from plotly) (1.41.0)
# Requirement already satisfied: packaging in /Users/richienodollar/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from plotly) (24.2)
# Requirement already satisfied: colormath in /Users/richienodollar/.pyenv/versions/3.10.0/lib/python3.10/site-packages (3.0.0)
# Requirement already satisfied: numpy in /Users/richienodollar/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from colormath) (2.1.3)
# Requirement already satisfied: networkx>=2.0 in /Users/richienodollar/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from colormath) (3.4.2)

# %%
import numpy as np
import pandas as pd
from pathlib import Path
import warnings
warnings.filterwarnings("ignore")

from tqdm.auto import tqdm
import matplotlib.pyplot as plt

# Import our custom modules
from chromatic_utils import (
    extract_dominant_colors_lab,
    calculate_color_statistics,
    load_sanzo_wada_palettes,
    find_closest_wada_palette,
    aggregate_by_year,
    aggregate_by_decade,
    get_palette_frequency_by_year,
    get_dominant_palette_per_decade,
    compute_decade_color_distance,
    analyze_by_designer,
    analyze_by_season,
    plot_temporal_trends,
    plot_palette_heatmap,
    plot_color_diversity,
    plot_decade_color_strips,
    plot_top_palettes,
    plot_lab_distribution,
    plot_seasonal_comparison,
    create_summary_visualization
)

print("✓ All libraries loaded successfully")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 11
#       8 import matplotlib.pyplot as plt
#      10 # Import our custom modules
# ---> 11 from chromatic_utils import (
#      12     extract_dominant_colors_lab,
#      13     calculate_color_statistics,
#      14     load_sanzo_wada_palettes,
#      15     find_closest_wada_palette,
#      16     aggregate_by_year,
#      17     aggregate_by_decade,
#      18     get_palette_frequency_by_year,
#      19     get_dominant_palette_per_decade,
#      20     compute_decade_color_distance,
#      21     analyze_by_designer,
#      22     analyze_by_season,
#      23     plot_temporal_trends,
#      24     plot_palette_heatmap,
#      25     plot_color_diversity,
#      26     plot_decade_color_strips,
#      27     plot_top_palettes,
#      28     plot_lab_distribution,
#      29     plot_seasonal_comparison,
#      30     create_summary_visualization
#      31 )
#      33 print("✓ All libraries loaded successfully")
#
# File ~/Desktop/stats master/ws25/css/project_css/chromatic_utils/__init__.py:10
#       7 __version__ = "1.0.0"
#       8 __author__ = "Chromatic Mood Project"
# ---> 10 from .color_extraction import (
#      11     load_and_preprocess_image,
#      12     rgb_to_lab,
#      13     extract_dominant_colors_lab,
#      14     lab_to_rgb,
#      15     lab_opencv_to_colormath,
#      16     calculate_color_statistics
#      17 )
#      19 from .sanzo_wada import (
#      20     load_sanzo_wada_palettes,
#      21     find_closest_wada_palette,
#      22     translate_palette_name,
#      23     PALETTE_NAME_TRANSLATIONS
#      24 )
#      26 from .temporal_analysis import (
#      27     aggregate_by_year,
#      28     aggregate_by_decade,
#    (...)
#      33     analyze_by_season
#      34 )
#
# File ~/Desktop/stats master/ws25/css/project_css/chromatic_utils/color_extraction.py:12
#      10 import cv2
#      11 from sklearn.cluster import KMeans
# ---> 12 from colormath.color_objects import LabColor
#      15 def load_and_preprocess_image(image_path, target_size=256):
#      16     """
#      17     Load an image and prepare it for color extraction.
#      18
#    (...)
#      24         numpy array in RGB format, or None if error
#      25     """
#
# ModuleNotFoundError: No module named 'colormath'

# %% [markdown]
# ## 2. Configuration

# %%
# Paths
DATA_CSV = Path("vogue_dataset_output/vogue_runway_merged_30k.csv")
OUTPUT_DIR = Path("chromatic_analysis_output")
OUTPUT_DIR.mkdir(exist_ok=True)

# Processing parameters
IMAGE_RESIZE = 256  # Resize for faster processing
N_CLUSTERS = 6      # Dominant colors per image
SAMPLE_SIZE = None  # Set to int (e.g. 1000) for testing

# Analysis parameters
MIN_YEAR = 1988
MAX_YEAR = 2025

print(f"Output directory: {OUTPUT_DIR.absolute()}")

# %% [markdown]
# ## 3. Load Data

# %%
df = pd.read_csv(DATA_CSV)
print(f"Loaded {len(df):,} images")

# Filter and clean
df = df[(df["year"] >= MIN_YEAR) & (df["year"] <= MAX_YEAR)].copy()
df = df[df["has_image"] == True].copy()
df = df.dropna(subset=["image_path", "year"])

if SAMPLE_SIZE:
    df = df.sample(n=min(SAMPLE_SIZE, len(df)), random_state=42)

df = df.reset_index(drop=True)
print(f"Filtered: {len(df):,} images from {df['year'].min()} to {df['year'].max()}")
df.head()

# %% [markdown]
# ## 4. Load Sanzo Wada Palettes

# %%
df_sanzo = load_sanzo_wada_palettes()
df_sanzo.head(10)

# %% [markdown]
# ## 5. Extract Colors and Map to Palettes
#
# This step processes all images to extract dominant colors and map them to Sanzo Wada palettes.
# **Note:** This may take several minutes for large datasets.

# %%
results = []

print(f"Processing {len(df)} images...")

for idx, row in tqdm(df.iterrows(), total=len(df), desc="Extracting colors"):
    image_path = row["image_path"]
    
    # Extract colors
    color_data = extract_dominant_colors_lab(image_path, n_colors=N_CLUSTERS, target_size=IMAGE_RESIZE)
    if color_data is None:
        continue
    
    # Map to Sanzo Wada
    wada_match = find_closest_wada_palette(
        color_data["colors_lab"],
        df_sanzo,
        weights=color_data["proportions"]
    )
    
    # Calculate statistics
    stats = calculate_color_statistics(color_data["colors_lab"], color_data["proportions"])
    
    results.append({
        "key": row["key"],
        "designer": row["designer"],
        "year": row["year"],
        "season": row["season"],
        "category": row["category"],
        "image_path": image_path,
        "palette_id": wada_match["palette_id"],
        "palette_name": wada_match["palette_name"],
        "palette_distance": wada_match["mean_distance"],
        **stats
    })

df_results = pd.DataFrame(results)
print(f"✓ Processed {len(df_results):,} images")

# Save results
df_results.to_csv(OUTPUT_DIR / "color_analysis_results.csv", index=False)
df_results.head()

# %% [markdown]
# ## 6. Temporal Analysis

# %%
# Aggregate by year
yearly_stats = aggregate_by_year(df_results)
print("Yearly Statistics:")
print(yearly_stats.head())

# Aggregate by decade
decade_stats = aggregate_by_decade(df_results)
print("\nDecade Statistics:")
print(decade_stats)

# Palette frequencies
palette_by_year = get_palette_frequency_by_year(df_results)
top_palettes = df_results["palette_id"].value_counts().head(15).index.tolist()

# %% [markdown]
# ## 7. Visualizations

# %% [markdown]
# ### 7.1 Summary Dashboard

# %%
create_summary_visualization(yearly_stats, OUTPUT_DIR / "summary_dashboard.png")
plt.show()

# %% [markdown]
# ### 7.2 Temporal Trends

# %%
plot_temporal_trends(yearly_stats, OUTPUT_DIR / "temporal_trends.png")
plt.show()

# %% [markdown]
# ### 7.3 Palette Frequency Heatmap

# %%
plot_palette_heatmap(palette_by_year, top_palettes, OUTPUT_DIR / "palette_heatmap.png")
plt.show()

# %% [markdown]
# ### 7.4 Color Diversity

# %%
plot_color_diversity(yearly_stats, OUTPUT_DIR / "color_diversity.png")
plt.show()

# %% [markdown]
# ### 7.5 Decade Color Strips

# %%
decade_palettes = get_dominant_palette_per_decade(df_results, df_sanzo)
plot_decade_color_strips(decade_palettes, OUTPUT_DIR / "decade_strips.png")
plt.show()

# %% [markdown]
# ### 7.6 Top Palettes

# %%
plot_top_palettes(df_results, n=10, output_path=OUTPUT_DIR / "top_palettes.png")
plt.show()

# %% [markdown]
# ### 7.7 LAB Color Distribution

# %%
plot_lab_distribution(df_results, OUTPUT_DIR / "lab_distribution.png")
plt.show()

# %% [markdown]
# ## 8. Additional Analysis

# %% [markdown]
# ### 8.1 Seasonal Analysis

# %%
season_stats = analyze_by_season(df_results)
print(season_stats)
plot_seasonal_comparison(season_stats, OUTPUT_DIR / "seasonal_comparison.png")
plt.show()

# %% [markdown]
# ### 8.2 Designer Analysis

# %%
designer_stats = analyze_by_designer(df_results, min_images=50)
print("Top designers by image count:")
print(designer_stats.head(10))
designer_stats.to_csv(OUTPUT_DIR / "designer_analysis.csv")

# %% [markdown]
# ### 8.3 Decade-to-Decade Color Distance

# %%
decade_distances = compute_decade_color_distance(df_results)
print(decade_distances)
decade_distances.to_csv(OUTPUT_DIR / "decade_distances.csv", index=False)

# %% [markdown]
# ## 9. Summary
#
# This notebook has analyzed the chromatic evolution of fashion imagery by:
#
# 1. **Extracting** dominant colors using K-Means in LAB space
# 2. **Mapping** colors to historical Sanzo Wada palettes
# 3. **Analyzing** temporal trends in lightness, saturation, and diversity
# 4. **Visualizing** the evolution across decades
# 5. **Comparing** seasonal and designer-specific color preferences
#
# All results have been saved to the output directory.

# %%
print(f"Analysis complete! Results saved to: {OUTPUT_DIR.absolute()}")
print("\nOutput files:")
for f in sorted(OUTPUT_DIR.glob("*")):
    print(f"  - {f.name}")
